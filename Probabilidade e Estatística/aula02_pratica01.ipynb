# %%
import pandas as pd
# Lendo um arquivo CSV (Ex: Dados de vendas de carros)
df1 = pd.read_csv('vendas_nissan.csv')
# Visualizando as primeiras 5 linhas

print(df1.head())

# %%
import pandas as pd
# Lendo um arquivo Excel
df2 = pd.read_excel('investimentos_etf.xlsx')
# Visualizando as últimas 5 linhas
print(df2.tail())
# Dimensões do dataset (linhas, colunas)
print(df2.shape)
